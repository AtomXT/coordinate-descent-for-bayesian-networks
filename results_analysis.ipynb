# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # results for small alpha

# %%
ges_small = pd.read_csv('experiment results/comparison with benchmarks/ges_results_est_default_reorder_small_diff.csv')
micodag_small = pd.read_csv('experiment results/comparison with benchmarks/micodag_est_12log(m)n_small_diff.csv')
td_small = pd.read_csv('experiment results/comparison with benchmarks/TD_RealGraph_est_small_diff.csv')
cd_small = pd.read_csv('experiment results/comparison with benchmarks/RealGraph_est_reorder_small_diff.csv')
notears_small = pd.read_csv('experiment results/comparison with benchmarks/notears_est_small_diff.csv')
ccdr_small = pd.read_csv('experiment results/comparison with benchmarks/ccdr_mcp_small_diff.csv')

ges_small = ges_small.set_index(['dataset'])
micodag_small = micodag_small.set_index(['dataset'])
td_small = td_small.set_index(['dataset'])
cd_small = cd_small.set_index(['dataset'])
notears_small = notears_small.set_index(['dataset'])
ccdr_small = ccdr_small.set_index(['dataset'])

# %%
mean_results = micodag_small.groupby('dataset').mean()
std_results = micodag_small.groupby('dataset').std()
print(pd.DataFrame({'Time': mean_results['Time'], 'RGAP':mean_results['RGAP'], 'mean': mean_results['d_cpdag'], 'std': std_results['d_cpdag']}))
# Out:
#                         Time          RGAP  mean       std
# dataset
# 10factors        1490.880431  2.168674e-01  65.1  6.690790
# 11hfinder        3940.385958  1.558661e-01  12.9  4.094712
# 12hepar          4132.792508  7.324882e-01  32.6  6.535374
# 1dsep               0.788460  9.684864e-06   2.0  0.000000
# 2asia               2.727941  2.407150e-05   2.0  0.000000
# 3bowling            5.249215  2.938712e-08   2.0  0.000000
# 4insuranceSmall   568.927963  7.155783e-03  12.2  2.740641
# 5rain              36.719854  2.920290e-05   2.2  0.632456
# 6cloud             30.046217  1.598821e-05   5.0  0.000000
# 7funnel            14.387415  1.733773e-09   2.1  0.316228
# 8galaxy           125.362145  7.480861e-06   1.0  0.000000
# 9insurance       1379.505294  2.200325e-01  15.8  5.116422

# %%
mean_results = ccdr_small.groupby('dataset').mean()
std_results = ccdr_small.groupby('dataset').std()
print(pd.DataFrame({'Time': mean_results['Time'], 'mean': mean_results['d_cpdag'], 'std': std_results['d_cpdag']}))
# Out:
#                      Time  mean       std
# dataset
# 10factors        0.389078  65.1  6.367452
# 11hfinder        0.467829  14.9  3.842742
# 12hepar          0.926548  51.6  9.500877
# 1dsep            0.070249   2.0  0.000000
# 2asia            0.081349   2.3  0.948683
# 3bowling         0.088621   3.1  1.911951
# 4insuranceSmall  0.152921  27.0  4.082483
# 5rain            0.134928   8.5  2.121320
# 6cloud           0.150270   8.5  4.453463
# 7funnel          0.169013   3.3  1.702939
# 8galaxy          0.207668   9.1  4.332051
# 9insurance       0.265154  32.5  6.041523

# %%
mean_results = ges_small.groupby('dataset').mean()
std_results = ges_small.groupby('dataset').std()
print(pd.DataFrame({'Time': mean_results['Time'], 'mean': mean_results['d_cpdag'], 'std': std_results['d_cpdag']}))
# Out:
#                      Time  mean        std
# dataset
# 10factors        0.045131  67.0   8.259674
# 11hfinder        0.057345  29.6  11.654279
# 12hepar          0.168951  76.6  29.451278
# 1dsep            0.011982   2.0   0.000000
# 2asia            0.011972   2.1   0.316228
# 3bowling         0.019140   2.4   1.264911
# 4insuranceSmall  0.021120  20.2   5.692100
# 5rain            0.028462   4.2   3.326660
# 6cloud           0.029478   5.0   0.000000
# 7funnel          0.027193   8.9  10.289693
# 8galaxy          0.018969   2.1   3.478505
# 9insurance       0.059511  28.8   4.613988

# %%
mean_results = td_small.groupby('dataset').mean()
std_results = td_small.groupby('dataset').std()
print(pd.DataFrame({'Time': mean_results['Time'], 'mean': mean_results['d_cpdag'], 'std': std_results['d_cpdag']}))
# Out:
#                      Time  mean       std
# dataset
# 10factors        0.104499  18.7  3.917199
# 11hfinder        1.497892  14.1  7.340148
# 12hepar          3.599326  18.5  7.367345
# 1dsep            0.002515   2.0  0.000000
# 2asia            0.004118   3.2  1.932184
# 3bowling         0.005316   2.0  0.000000
# 4insuranceSmall  0.016222   8.0  0.000000
# 5rain            0.013806   2.0  0.000000
# 6cloud           0.024209   3.2  1.032796
# 7funnel          0.035985   2.0  0.000000
# 8galaxy          0.047093   1.2  0.632456
# 9insurance       0.124357  11.7  2.668749

# %%
mean_results = notears_small.groupby('dataset').mean()
std_results = notears_small.groupby('dataset').std()
print(pd.DataFrame({'Time': mean_results['Time'], 'mean': mean_results['d_cpdag'], 'std': std_results['d_cpdag']}))
# Out:
#                      Time  mean       std
# dataset
# 10factors        0.810533  18.4  4.273952
# 11hfinder        1.655268  18.2  3.881580
# 12hepar          3.212684  42.6  5.680376
# 1dsep            0.479443   2.0  0.000000
# 2asia            0.487567   2.8  1.751190
# 3bowling         0.523672   3.8  0.632456
# 4insuranceSmall  0.619598   6.7  1.494434
# 5rain            0.608892   3.4  2.503331
# 6cloud           0.619330  19.1  2.726414
# 7funnel          0.649407   3.2  1.549193
# 8galaxy          0.674093  17.0  2.905933
# 9insurance       0.823118  12.7  5.926400

# %%
mean_results = cd_small.groupby('dataset').mean()
std_results = cd_small.groupby('dataset').std()
print(pd.DataFrame({'Time': mean_results['Time'], 'mean': mean_results['d_cpdag'], 'std': std_results['d_cpdag']}))
# Out:
#                      Time  mean       std
# dataset
# 10factors        0.099401  20.9  4.280446
# 11hfinder        0.354134  14.7  9.189970
# 12hepar          1.226254  11.6  6.328068
# 1dsep            0.003482   2.0  0.000000
# 2asia            0.004725   3.2  1.932184
# 3bowling         0.007427   2.0  0.000000
# 4insuranceSmall  0.022325   8.0  0.000000
# 5rain            0.019904   2.0  0.000000
# 6cloud           0.030123   5.2  2.616189
# 7funnel          0.018452   2.0  0.000000
# 8galaxy          0.018182   1.2  0.632456
# 9insurance       0.110936  10.3  1.494434

# %% [markdown]
# # large graph

# %%
large_ccdr = pd.read_csv('experiment results/comparison on large graphs/ccdr_mcp_large_graph_small_diff.csv')
large_cd = pd.read_csv('experiment results/comparison on large graphs/cd_results_est_large_graph_small_diff.csv')
large_ges = pd.read_csv('experiment results/comparison on large graphs/ges_results_est_large_graph_small_diff.csv')

large_ccdr = large_ccdr.set_index(['dataset'])
large_cd = large_cd.set_index(['dataset'])
large_ges = large_ges.set_index(['dataset'])

# %%
mean_results = large_cd.groupby('dataset').mean()
std_results = large_cd.groupby('dataset').std()
pd.DataFrame(np.array([mean_results.index, mean_results['Time'], mean_results['d_cpdag'], std_results['d_cpdag']]).T, columns=['network', 'time','d_cpdag', 'std'])
# Out:
#         network     time d_cpdag      std
# 0  13pathfinder  23.9622      95  18.4029
# 1       15andes  108.885    98.4  6.81828
# 2    16diabetes  732.281   158.4  10.7621

# %%
mean_results = large_ccdr.groupby('dataset').mean()
std_results = large_ccdr.groupby('dataset').std()
pd.DataFrame(np.array([mean_results.index, mean_results['Time'], mean_results['d_cpdag'], std_results['d_cpdag']]).T, columns=['network', 'time','d_cpdag', 'std'])
# Out:
#         network     time d_cpdag      std
# 0  13pathfinder  5.45084   206.6  4.85798
# 1       15andes  12.6041   121.5  5.23344
# 2    16diabetes  42.5736   322.9  9.38616

# %%
mean_results = large_ges.groupby('dataset').mean()
std_results = large_ges.groupby('dataset').std()
pd.DataFrame(np.array([mean_results.index, mean_results['Time'], mean_results['d_cpdag'], std_results['d_cpdag']]).T, columns=['network', 'time','d_cpdag', 'std'])
# Out:
#         network      time d_cpdag      std
# 0  13pathfinder  0.845494   253.8  19.5152
# 1       15andes   1.89591   152.8  22.2601
# 2    16diabetes   10.7079   458.7  28.7288

# %% [markdown]
# # obj difference

# %%
cd_results_obj = pd.read_csv('./experiment results/synthetic_results_CD_order_small_diff.csv')
ges_results_obj = pd.read_csv('./experiment results/synthetic_results_ges_small_alpha.csv')
micodag_results_obj = pd.read_csv('./experiment results/synthetic_results_micodag_small_diff.csv')
cd_results_obj['Method'] = 'Our method'
micodag_results_obj['Method'] = 'MICODAG'
ges_results_obj['Method'] = 'GES'
micodag_results_obj = micodag_results_obj[micodag_results_obj['RGAP'] < 0.01]
all_results_obj1 = pd.concat([cd_results_obj, micodag_results_obj, ges_results_obj])
cd_obj_diff_ratio = (all_results_obj1[all_results_obj1.Method == 'Our method'].obj - all_results_obj1[all_results_obj1.Method == 'MICODAG'].obj)/all_results_obj1[all_results_obj1.Method == 'MICODAG'].obj
cd_obj_diff_ratio[cd_obj_diff_ratio<0] = 0
ges_obj_diff_ratio = (all_results_obj1[all_results_obj1.Method == 'GES'].obj - all_results_obj1[all_results_obj1.Method == 'MICODAG'].obj)/all_results_obj1[all_results_obj1.Method == 'MICODAG'].obj
ges_obj_diff_ratio[ges_obj_diff_ratio<0] = 0
obj_diff_ratio = pd.DataFrame(micodag_results_obj[['graph', 'n_sample', 'iter']])
obj_diff_ratio['Our method'] = cd_obj_diff_ratio
obj_diff_ratio['GES'] = ges_obj_diff_ratio
obj_diff_ratio = obj_diff_ratio.set_index(['graph', 'n_sample'])
# Out:
# /software/python-anaconda3/2019.10/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
obj_diff_mean = obj_diff_ratio['Our method'].groupby(level=['n_sample','graph']).mean()
temp_obj = obj_diff_mean.unstack(['graph'])
plt.plot([100, 200, 300, 400, 500, 800, 1000, 1600, 3200], temp_obj.iloc[1:,0], "-x")
plt.plot([100, 200, 300, 400, 500, 800, 1000, 1600, 3200], temp_obj.iloc[1:,1], '-o')
plt.plot([100, 200, 300, 400, 500, 800, 1000, 1600, 3200], temp_obj.iloc[1:,2], '-s')
plt.xlabel('n', fontsize=15)
plt.ylabel('Percentage of differences', fontsize=15)
# plt.legend(['Graph1 (7 edges)', 'Graph2 (12 edges)'], fontsize=15)
plt.legend(['Graph1 (7 edges)', 'Graph2 (12 edges)', 'Graph3 (21 edges)'], fontsize=15)
plt.savefig('./experiment results/plots/obj_diff_new.pdf')
plt.show()

# %%
ges_obj_diff_mean = obj_diff_ratio['GES'].groupby(level=['n_sample', 'graph']).mean()
ges_temp_obj = ges_obj_diff_mean.unstack(['graph'])
plt.plot([100, 200, 300, 400, 500, 800, 1000, 1600, 3200], ges_temp_obj.iloc[1:,0], "-x")
plt.plot([100, 200, 300, 400, 500, 800, 1000, 1600, 3200], ges_temp_obj.iloc[1:,1], '-o')
plt.plot([100, 200, 300, 400, 500, 800, 1000, 1600, 3200], ges_temp_obj.iloc[1:,2], '-s')
plt.xlabel('n', fontsize=15)
plt.ylabel('Percentage of differences', fontsize=15)
plt.legend(['Graph1 (7 edges)', 'Graph2 (12 edges)', 'Graph3 (21 edges)'], fontsize=15)
# plt.legend(['Graph1 (7 edges)', 'Graph2 (12 edges)'], fontsize=15)
plt.savefig('./experiment results/plots/ges_obj_diff_new.pdf')
plt.show()

# %%
all_results_obj = pd.concat([cd_results_obj, micodag_results_obj, ges_results_obj])
all_results_obj = all_results_obj.set_index(['graph', 'n_sample', 'Method'])
obj_time_mean = all_results_obj['time'].groupby(level=['n_sample','graph', 'Method']).mean()
temp = obj_time_mean.unstack(['graph', 'Method'])
obj_time_figure = plt.figure()
plt.plot([100, 200, 300, 400, 500, 800, 1000, 1600, 3200],temp.iloc[1:,8],'-x', label='CD', color='red')
plt.plot([100, 200, 300, 400, 500, 800, 1000, 1600, 3200],temp.iloc[1:,7], '-s', label='MICODAG', color='c')
plt.plot([100, 200, 300, 400, 500, 800, 1000, 1600, 3200],temp.iloc[1:,6],'--o', label='GES', color='blue')
plt.legend(fontsize=15)
plt.grid(False)
plt.ylabel('Time (seconds)', fontsize=15)
plt.xlabel('n', fontsize=15)
plt.savefig('./experiment results/plots/obj_time_graph3_new.pdf')
plt.show()
# Out:
# /software/python-anaconda3/2019.10/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Objective convergence with random orderings

# %%
cd_results0_obj = pd.read_csv('./experiment results/synthetic_results_CD_order_small_diff_random_ordering0.csv')
cd_results1_obj = pd.read_csv('./experiment results/synthetic_results_CD_order_small_diff_random_ordering1.csv')
cd_results2_obj = pd.read_csv('./experiment results/synthetic_results_CD_order_small_diff_random_ordering2.csv')
micodag_results_obj = pd.read_csv('./experiment results/synthetic_results_micodag_small_diff.csv')
cd_results0_obj['Method'] = 'CD random ordering1'
cd_results1_obj['Method'] = 'CD random ordering2'
cd_results2_obj['Method'] = 'CD random ordering3'
micodag_results_obj['Method'] = 'MICODAG'

micodag_results_obj = micodag_results_obj[micodag_results_obj['RGAP'] < 0.01]
all_results_obj1 = pd.concat([cd_results0_obj, cd_results1_obj,cd_results2_obj, micodag_results_obj])
cd_obj_diff_ratio1 = (all_results_obj1[all_results_obj1.Method == 'CD random ordering1'].obj - all_results_obj1[all_results_obj1.Method == 'MICODAG'].obj)/all_results_obj1[all_results_obj1.Method == 'MICODAG'].obj
cd_obj_diff_ratio1[cd_obj_diff_ratio1<0] = 0
cd_obj_diff_ratio2 = (all_results_obj1[all_results_obj1.Method == 'CD random ordering2'].obj - all_results_obj1[all_results_obj1.Method == 'MICODAG'].obj)/all_results_obj1[all_results_obj1.Method == 'MICODAG'].obj
cd_obj_diff_ratio2[cd_obj_diff_ratio2<0] = 0
cd_obj_diff_ratio3 = (all_results_obj1[all_results_obj1.Method == 'CD random ordering3'].obj - all_results_obj1[all_results_obj1.Method == 'MICODAG'].obj)/all_results_obj1[all_results_obj1.Method == 'MICODAG'].obj
cd_obj_diff_ratio3[cd_obj_diff_ratio3<0] = 0

obj_diff_ratio = pd.DataFrame(micodag_results_obj[['graph', 'n_sample', 'iter']])
obj_diff_ratio['CD(ordering1)'] = cd_obj_diff_ratio1
obj_diff_ratio['CD(ordering2)'] = cd_obj_diff_ratio2
obj_diff_ratio['CD(ordering3)'] = cd_obj_diff_ratio3
obj_diff_ratio = obj_diff_ratio.loc[obj_diff_ratio['graph'] == 1,]
obj_diff_ratio = obj_diff_ratio.set_index(['n_sample'])
# Out:
# /software/python-anaconda3/2019.10/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   # This is added back by InteractiveShellApp.init_path()

# %%
obj_diff_ratio.groupby(level=['n_sample']).mean()
# Out:
#           graph  iter  CD(ordering1)  CD(ordering2)  CD(ordering3)
# n_sample
# 50          1.0   5.5       0.016561       0.010209   2.154421e-03
# 100         1.0   6.0       0.016908       0.011687   3.023726e-03
# 200         1.0   5.5       0.012888       0.005395   3.722264e-04
# 300         1.0   5.5       0.009102       0.003171   6.132633e-07
# 400         1.0   5.5       0.007563       0.002542   7.130262e-07
# 500         1.0   5.5       0.006254       0.002002   5.996687e-07
# 800         1.0   5.5       0.003903       0.001382   6.565625e-07
# 1000        1.0   5.5       0.003117       0.000996   5.678097e-07
# 1600        1.0   5.5       0.001927       0.000613   6.252427e-07
# 3200        1.0   5.5       0.000873       0.000267   7.124394e-07

# %%
obj_diff_mean = obj_diff_ratio.groupby(level=['n_sample']).mean()
plt.plot([50, 100, 200, 300, 400, 500, 800, 1000, 1600, 3200], obj_diff_mean.iloc[1:,2], "-x")
plt.plot([50, 100, 200, 300, 400, 500, 800, 1000, 1600, 3200], obj_diff_mean.iloc[1:,3], '-o')
plt.plot([50, 100, 200, 300, 400, 500, 800, 1000, 1600, 3200], obj_diff_mean.iloc[1:,4], '-s')
plt.xlabel('n', fontsize=15)
plt.ylabel('Percentage of differences', fontsize=15)
# plt.legend(['Graph1 (7 edges)', 'Graph2 (12 edges)'], fontsize=15)
plt.legend(['CD(ordering1)', 'CD(ordering2)', 'CD(ordering3)'], fontsize=15)
# plt.savefig('./experiment results/plots/obj_diff_new.pdf')
plt.show()

# %%
obj_diff_mean.iloc[1:,2]
# Out:
# n_sample
# 100     0.011687
# 200     0.005395
# 300     0.003171
# 400     0.002542
# 500     0.002002
# 800     0.001382
# 1000    0.000996
# 1600    0.000613
# 3200    0.000267
# Name: CD(ordering1), dtype: float64

# %%
obj_diff_mean.iloc[1:,3]
# Out:
# n_sample
# 100     3.023726e-03
# 200     3.722264e-04
# 300     6.132633e-07
# 400     7.130262e-07
# 500     5.996687e-07
# 800     6.565625e-07
# 1000    5.678097e-07
# 1600    6.252427e-07
# 3200    7.124394e-07
# Name: CD(ordering2), dtype: float64
